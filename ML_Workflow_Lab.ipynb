# %% [markdown]
# # Machine Learning Workflow Lab

# %%
import pandas as pd

# %%
# Load the dataset with correct headers
headers = ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country', 'Postal Code', 'Market', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost', 'Order Priority']
df = pd.read_csv('superstore_dataset2011-2015.csv', encoding='latin1')

# %%
# Display dataset shape
df.shape

# %%
# Preview first few rows
df.head()

# %%
# Check column names and data types
print("Column Names:", df.columns)
print("\nData Types:")
print(df.dtypes)

# %% [markdown]
# ## Methodology Diagram
#
# ```mermaid
# graph TD
#     A[Dataset Selection] --> B[Data Loading]
#     B --> C[Data Preprocessing]
#     C --> D[Train/Test Split]
#     D --> E[Model Training]
#     E --> F[Model Evaluation]
#     F --> G[Results]
# ```
